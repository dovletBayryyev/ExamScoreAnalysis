# %%
# importing libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
# reading the exams dataset
df = pd.read_csv('exams.csv')

# %% [markdown]
# ## Section 1. Cleaning / Pre-processing data

# %%
df = df.dropna() # drops NaN values 
print(df[df.isna().any(axis=1)]) # shows NaN values in data frame if it exists
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
# Adding total_score column which combines the math,reading,and writing score
df['total_score'] = sum([df['math score'],df['reading score'],df['writing score']])

# %%
# To keep blank copy of the data
df1 = df.copy()

# %%
# dropping the math, reading, and writing score columns since we have created a new total_score column
columns_to_drop = ['math score', 'reading score','writing score']
df.drop(columns_to_drop, axis=1, inplace=True)

# %%
# printing the columns
print(df.columns.tolist())
# Out:
# ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'total_score']

# %% [markdown]
# ## Section 2. Data Exploration

# %%
def bar_plot(variable):
    
    var = df[variable]
    
    varValue = var.value_counts()
    

    plt.figure(figsize =(5,5))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values,rotation=45)
    plt.ylabel("Frequency")
    plt.title(variable)
        # Ensure the plot fits within the figure boundaries
    plt.tight_layout()
    

    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
category1 = ["gender","race/ethnicity","parental level of education","lunch","test preparation course"]

for c in category1:
    
    bar_plot(c)
# Out:
# gender:
#  gender
# male      517
# female    483
# Name: count, dtype: int64
# race/ethnicity:
#  race/ethnicity
# group C    323
# group D    262
# group B    205
# group E    131
# group A     79
# Name: count, dtype: int64
# parental level of education:
#  parental level of education
# some college          222
# associate's degree    203
# high school           202
# some high school      191
# bachelor's degree     112
# master's degree        70
# Name: count, dtype: int64
# lunch:
#  lunch
# standard        652
# free/reduced    348
# Name: count, dtype: int64
# test preparation course:
#  test preparation course
# none         665
# completed    335
# Name: count, dtype: int64

# %% [markdown]
# ## Section 3. EDA Algorithm

# %%
# describes the total score
print(df.describe())
# Out:
#        total_score
# count  1000.000000
# mean    203.136000
# std      43.542732
# min      65.000000
# 25%     175.750000
# 50%     202.000000
# 75%     235.000000
# max     300.000000

# %%
# Displaying the frequency table of “race/ethnicity” vs. lunch
frequency_table = df.groupby(['race/ethnicity','lunch']).size().reset_index(name='Frequency')
print(frequency_table)
# Out:
#   race/ethnicity         lunch  Frequency
# 0        group A  free/reduced         26
# 1        group A      standard         53
# 2        group B  free/reduced         70
# 3        group B      standard        135
# 4        group C  free/reduced        115
# 5        group C      standard        208
# 6        group D  free/reduced         78
# 7        group D      standard        184
# 8        group E  free/reduced         59
# 9        group E      standard         72

# %%
# Displaying the frequency table of “race/ethnicity” vs. test preparation course
frequency_table = df.groupby(['race/ethnicity','test preparation course']).size().reset_index(name='Frequency')
print(frequency_table)
# Out:
#   race/ethnicity test preparation course  Frequency
# 0        group A               completed         32
# 1        group A                    none         47
# 2        group B               completed         72
# 3        group B                    none        133
# 4        group C               completed        102
# 5        group C                    none        221
# 6        group D               completed         84
# 7        group D                    none        178
# 8        group E               completed         45
# 9        group E                    none         86

# %%
# Displaying the frequency table of “race/ethnicity” vs. test preparation course
frequency_table = df.groupby(['race/ethnicity','parental level of education']).size().reset_index(name='Frequency')
print(frequency_table)
# Out:
#    race/ethnicity parental level of education  Frequency
# 0         group A          associate's degree         11
# 1         group A           bachelor's degree         14
# 2         group A                 high school         15
# 3         group A             master's degree          8
# 4         group A                some college         20
# 5         group A            some high school         11
# 6         group B          associate's degree         40
# 7         group B           bachelor's degree         20
# 8         group B                 high school         39
# 9         group B             master's degree         19
# 10        group B                some college         49
# 11        group B            some high school         38
# 12        group C          associate's degree         75
# 13        group C           bachelor's degree         35
# 14        group C                 high school         58
# 15        group C             master's degree         20
# 16        group C                some college         69
# 17        group C            some high school         66
# 18        group D          associate's degree         50
# 19        group D           bachelor's degree         29
# 20        group D                 high school         59
# 21        group D             master's degree         16
# 22        group D                some college         57
# 23        group D            some high school         51
# 24        group E          associate's degree         27
# 25        group E           bachelor's degree         14
# 26        group E                 high school         31
# 27        group E             master's degree          7
# 28        group E                some college         27
# 29        group E            some high school         25

# %%
# Show histogram for total_score column
plt.hist(df['total_score'], bins=10, color='blue', alpha=0.6,rwidth=0.9)
plt.xlabel('Total Score')
plt.ylabel('Frequency')
plt.title('Histogram of Total Scores')
plt.show()

# %%
# creating new data frames depending on the race/ethnicity to use in our box plots
E_df = df.loc[df['race/ethnicity'] == 'group E']
D_df = df.loc[df['race/ethnicity'] == 'group D']
B_df = df.loc[df['race/ethnicity'] == 'group B']
C_df = df.loc[df['race/ethnicity'] == 'group C']
A_df = df.loc[df['race/ethnicity'] == 'group A']

# %%
# creating box plots of total scores for different races in the dataset 
fig, ax = plt.subplots()
ax.boxplot([A_df['total_score'], B_df['total_score'], C_df['total_score'], D_df['total_score'],E_df['total_score']], labels=['Group A', 'Group B', 'Group C', 'Group D', 'Group E'])
ax.set_title('Boxplots of total scores for different racial groups')
ax.set_xlabel('Race/Ethnicity')
ax.set_ylabel('Total Score')
plt.show()

# %%
# Function to remove outliers based on boxplot
def remove_outliers_boxplot(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Specify columns to check for outliers
columns_to_check = ['race/ethnicity']

# Remove outliers from specified columns based on boxplot
#df_no_outliers_boxplot = remove_outliers_boxplot(df, columns_to_check)

# %% [markdown]
# ## Section 4. Knn Algorithm

# %%
# Function to convert total_score to letter grade
def score_to_grade(score):
    if score >= 250:
        return 'Excellent'
    elif score >= 170:
        return 'Average'
    else:
        return 'Fail'

# %%
# Apply the function to update the total score from number to a letter grade
df['total_score_letter'] = df['total_score'].apply(score_to_grade)

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()
# Encode the 'Gender' column --> 0 for female, 1 for Male
df['gender'] = label_encoder.fit_transform(df['gender'])
df['race/ethnicity'] = label_encoder.fit_transform(df['race/ethnicity'])
df['parental level of education'] = label_encoder.fit_transform(df['parental level of education'])
df['test preparation course'] = label_encoder.fit_transform(df['test preparation course'])
df['lunch'] = label_encoder.fit_transform(df['lunch'])

# %%
# Splitting the dataset
attr = df.drop(columns = ['total_score_letter','total_score'])  # features
target = df['total_score_letter']  # target variable

# %%
# Splitting dataset into 30% test and 70% training data with random_state as 0
attr_train, attr_test, target_train,target_test  = train_test_split(attr, target,test_size = 0.3,train_size=0.7, random_state = 0, shuffle = True)

# %%
# Training the knn models using k = 3,5,10 values
k_values = [3, 5, 10]

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(attr_train, target_train)
    target_pred = knn.predict(attr_test)
    accuracy = accuracy_score(target_test,target_pred ) 
    cm = confusion_matrix(target_test, target_pred)
    cr = classification_report(target_test, target_pred)
    print(f'Accuracy of model with k = {k}: {accuracy}')
    print('')
    print(f'Classification Report of model with k = {k}:\n {cr}\n')
    
  
    print('--------------------------------------------------------------------------------')
# Out:
# Accuracy of model with k = 3: 0.5966666666666667
#
# Classification Report of model with k = 3:
#                precision    recall  f1-score   support
#
#      Average       0.68      0.77      0.72       197
#    Excellent       0.27      0.15      0.19        41
#         Fail       0.39      0.35      0.37        62
#
#     accuracy                           0.60       300
#    macro avg       0.45      0.42      0.43       300
# weighted avg       0.57      0.60      0.58       300
#
#
# --------------------------------------------------------------------------------
# Accuracy of model with k = 5: 0.6333333333333333
#
# Classification Report of model with k = 5:
#                precision    recall  f1-score   support
#
#      Average       0.69      0.85      0.76       197
#    Excellent       0.29      0.15      0.19        41
#         Fail       0.47      0.27      0.35        62
#
#     accuracy                           0.63       300
#    macro avg       0.48      0.42      0.43       300
# weighted avg       0.59      0.63      0.60       300
#
#
# --------------------------------------------------------------------------------
# Accuracy of model with k = 10: 0.63
#
# Classification Report of model with k = 10:
#                precision    recall  f1-score   support
#
#      Average       0.66      0.93      0.77       197
#    Excellent       0.40      0.10      0.16        41
#         Fail       0.18      0.03      0.05        62
#
#     accuracy                           0.63       300
#    macro avg       0.41      0.35      0.33       300
# weighted avg       0.52      0.63      0.54       300
#
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Section 5. Naive Bayes Model

# %%
from sklearn.naive_bayes import CategoricalNB
# Create a Categorical Naive Bayes model
model = CategoricalNB()

# Train the model
model.fit(attr_train, target_train)
# Make predictions on the test set
target_pred = model.predict(attr_test)

# %%
# Evaluate the accuracy
accuracy = accuracy_score(target_test, target_pred)
print(f'Accuracy: {accuracy}')
print()
print(confusion_matrix(target_test, target_pred))
print()
print('Classification Report')
print(classification_report(target_test, target_pred))
# Out:
# Accuracy: 0.6533333333333333
#
# [[181   6  10]
#  [ 33   8   0]
#  [ 54   1   7]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#      Average       0.68      0.92      0.78       197
#    Excellent       0.53      0.20      0.29        41
#         Fail       0.41      0.11      0.18        62
#
#     accuracy                           0.65       300
#    macro avg       0.54      0.41      0.41       300
# weighted avg       0.60      0.65      0.59       300

# %% [markdown]
# ### Section 6. CART Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz, export_text
# Create the CART model
model = DecisionTreeClassifier()
# Train the model
model.fit(attr_train, target_train)
# Make predictions on the test set
target_pred = model.predict(attr_test)

# %%
# Evaluation of the model
accuracy = accuracy_score(target_test, target_pred)
print(f'Accuracy: {accuracy}')
print()
print(confusion_matrix(target_test, target_pred))
print()
print('Classification Report')
print(classification_report(target_test, target_pred))
tree_rules = export_text(model, feature_names=list(attr.columns))
print("CART Tree Rules:\n", tree_rules)
# Out:
# Accuracy: 0.5933333333333334
#
# [[161  15  21]
#  [ 34   7   0]
#  [ 47   5  10]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#      Average       0.67      0.82      0.73       197
#    Excellent       0.26      0.17      0.21        41
#         Fail       0.32      0.16      0.22        62
#
#     accuracy                           0.59       300
#    macro avg       0.42      0.38      0.38       300
# weighted avg       0.54      0.59      0.55       300
#
# CART Tree Rules:
#  |--- lunch <= 0.50
# |   |--- test preparation course <= 0.50
# |   |   |--- parental level of education <= 4.50
# |   |   |   |--- gender <= 0.50
# |   |   |   |   |--- race/ethnicity <= 2.50
# |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 3.00
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |   |--- parental level of education >  3.00
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- race/ethnicity >  2.50
# |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.00
# |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |--- parental level of education >  1.00
# |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.00
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  1.00
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |--- gender >  0.50
# |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 2.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  2.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |--- race/ethnicity <= 2.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  2.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |--- parental level of education >  4.50
# |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |--- race/ethnicity <= 1.00
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  1.00
# |   |   |   |   |   |   |--- race/ethnicity <= 2.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  2.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |--- race/ethnicity <= 2.50
# |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  2.50
# |   |   |   |   |   |   |--- class: Fail
# |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |--- class: Fail
# |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |--- class: Average
# |   |--- test preparation course >  0.50
# |   |   |--- race/ethnicity <= 2.50
# |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |--- race/ethnicity >  2.50
# |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- class: Average
# |--- lunch >  0.50
# |   |--- race/ethnicity <= 2.50
# |   |   |--- test preparation course <= 0.50
# |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |--- test preparation course >  0.50
# |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |--- race/ethnicity <= 0.50
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- class: Fail
# |   |   |   |   |--- race/ethnicity >  0.50
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- race/ethnicity <= 1.50
# |   |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  1.50
# |   |   |   |   |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |--- race/ethnicity >  2.50
# |   |   |--- test preparation course <= 0.50
# |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |--- parental level of education <= 1.00
# |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |--- parental level of education >  1.00
# |   |   |   |   |   |   |   |--- parental level of education <= 3.00
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  3.00
# |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |--- class: Excellent
# |   |   |--- test preparation course >  0.50
# |   |   |   |--- parental level of education <= 4.50
# |   |   |   |   |--- parental level of education <= 3.50
# |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |--- parental level of education <= 0.50
# |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- parental level of education >  0.50
# |   |   |   |   |   |   |   |--- parental level of education <= 1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |   |--- parental level of education >  1.50
# |   |   |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- parental level of education >  3.50
# |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- class: Excellent
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |   |   |--- class: Fail
# |   |   |   |--- parental level of education >  4.50
# |   |   |   |   |--- gender <= 0.50
# |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |--- gender >  0.50
# |   |   |   |   |   |--- race/ethnicity <= 3.50
# |   |   |   |   |   |   |--- class: Average
# |   |   |   |   |   |--- race/ethnicity >  3.50
# |   |   |   |   |   |   |--- class: Average

# %% [markdown]
# ### Section 7. Random Forest

# %%
# creating the model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100,random_state=8)

# %%
# Train the model
model.fit(attr_train,target_train)
# Make predictions on the test set
target_pred = model.predict(attr_test)

# %%
# Evaluation of the model
print(f"Accuracy= {accuracy_score(target_test,target_pred)}")

print(confusion_matrix(target_test,target_pred))
print(classification_report(target_test,target_pred))
# Out:
# Accuracy= 0.5966666666666667
# [[156  16  25]
#  [ 31   9   1]
#  [ 42   6  14]]
#               precision    recall  f1-score   support
#
#      Average       0.68      0.79      0.73       197
#    Excellent       0.29      0.22      0.25        41
#         Fail       0.35      0.23      0.27        62
#
#     accuracy                           0.60       300
#    macro avg       0.44      0.41      0.42       300
# weighted avg       0.56      0.60      0.57       300

# %%
# Feature importance for Mean Decrease Accuracy
mean_decrease_accuracy = model.feature_importances_
print(f"Mean Decrease Accuracy{ mean_decrease_accuracy}")
# # Feature importance for Mean Decrease GINI
gini_importance = model.feature_importances_ * model.estimators_[0].tree_.impurity[0]
print(f"\nMean Decrease GINI= {gini_importance}")
# Out:
# Mean Decrease Accuracy[0.09512009 0.30264952 0.37081802 0.13295714 0.09845523]
#
# Mean Decrease GINI= [0.05335771 0.16977156 0.20801075 0.07458245 0.05522856]

# %%
# creating the plot (Mean Decrease Accuracy)
plt.figure(figsize=(10, 22))
plt.barh(range(len(mean_decrease_accuracy)), mean_decrease_accuracy, align='center')
plt.yticks(range(len(mean_decrease_accuracy)), attr.columns)
plt.xlabel('Mean Decrease Accuracy')
plt.title('Feature Importance - Mean Decrease Accuracy')
plt.show()

# %%
# plot for Mean Decrease GINI
plt.figure(figsize=(10, 22))
plt.barh(range(len(gini_importance)), gini_importance, align='center')
plt.yticks(range(len(gini_importance)), attr.columns)
plt.xlabel('Mean Decrease GINI')
plt.title('Feature Importance - Mean Decrease GINI')
plt.show()

# %%
# displaying the feature scores (top is most important)
feature_scores = pd.Series(model.feature_importances_, index=attr_train.columns).sort_values(ascending=False)
pd.set_option('display.max_rows', None)  # Show all rows
print(feature_scores)
# Out:
# parental level of education    0.370818
# race/ethnicity                 0.302650
# lunch                          0.132957
# test preparation course        0.098455
# gender                         0.095120
# dtype: float64

# %% [markdown]
# ### Section 8. Ridge Regression (Additional technique studied outside of class)

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)

# %%
# Splitting the dataset (using total_score with values instead of letters)
attr = df.drop(columns = ['total_score','total_score_letter'])  # features
target = df['total_score']  # target variable

# %%
# Splitting dataset into 30% test and 70% training data with random_state as 0
attr_train, attr_test, target_train,target_test  = train_test_split(attr, target,test_size = 0.3,train_size=0.7, random_state = 0, shuffle = True)

# %%
# Fitting the training data into the model
ridge.fit(attr_train,target_train)
# Out:
# Ridge()

# %%
# Making predictions
target_pred=ridge.predict(attr_test)
print(target_pred)
# Out:
# [205.92480473 243.78158786 196.57070187 180.98980238 167.03930818
#  192.27699231 219.17311027 188.68547141 204.10483801 224.58459789
#  159.50517205 217.05046176 229.06440993 231.18705844 213.45894086
#  228.36222127 213.45894086 178.51605954 230.48486978 186.40129001
#  158.73848832 182.80976911 208.42311715 201.28000084 197.68847994
#  211.63897414 208.04745324 211.63897414 171.33301774 174.57344431
#  207.69635891 205.5737104  213.10784653 174.92453864 189.03656574
#  235.12967367 188.87503285 186.75238434 192.27699231 228.52721312
#  213.10784653 208.42311715 216.69936743 185.1185201  184.74285618
#  215.95725328 170.98192341 178.51605954 236.24745173 197.68847994
#  205.94937431 201.28000084 199.81112844 186.75238434 231.18705844
#  247.72420309 219.71030708 201.28000084 204.29094049 203.75374368
#  197.68847994 213.10784653 224.58459789 196.21960754 181.17590486
#  215.58158937 222.95073365 228.52721312 199.81112844 219.35921275
#  205.5737104  211.63897414 188.68547141 199.81112844 211.99006847
#  174.92453864 173.80676058 208.42311715 220.64198266 213.45894086
#  213.10784653 211.82507662 174.57344431 189.06113533 226.89334888
#  181.15133528 217.05046176 220.99307699 177.04718715 208.04745324
#  224.41960604 177.39828148 211.99006847 234.77857934 219.17311027
#  192.62808664 169.86414535 204.45593234 184.74285618 201.28000084
#  189.41222966 215.58158937 190.17891339 204.29094049 196.21960754
#  188.87503285 228.36222127 158.03629966 212.7567522  239.4878783
#  162.33000922 204.45593234 186.58739249 220.64198266 208.81413697
#  174.57344431 242.6638098  239.4878783  224.58459789 232.3048365
#  225.1217947  188.87503285 240.19006696 243.78158786 169.51305102
#  194.28652047 205.94937431 169.51305102 181.34089672 208.04745324
#  211.28787981 179.21824821 194.47262295 224.23350356 185.28351195
#  228.52721312 177.74937582 211.63897414 201.9821895  205.5737104
#  219.35921275 213.10784653 208.04745324 194.28652047 205.5737104
#  204.10483801 243.78158786 193.7458647  177.39828148 232.65593083
#  208.81413697 188.68547141 220.82808514 211.63897414 211.99006847
#  203.75374368 201.63109517 216.88546991 208.04745324 170.98192341
#  204.12940759 177.04718715 186.58739249 217.07503134 196.94636579
#  240.19006696 208.07202282 236.24745173 224.23350356 181.15133528
#  146.91064263 159.85626638 171.33301774 225.1217947  201.28000084
#  247.72420309 212.7567522  242.6638098  192.81764808 215.76769185
#  212.7567522  204.29094049 240.19006696 244.13268219 226.89334888
#  203.75374368 177.39828148 185.1185201  204.10483801 194.28652047
#  197.68847994 178.51605954 216.3482731  220.64198266 212.7567522
#  211.99006847 216.88546991 175.27563298 154.44477876 228.36222127
#  242.6638098  171.33301774 196.21960754 198.41523818 192.62808664
#  174.57344431 203.75374368 204.45593234 193.35484489 215.95725328
#  158.73848832 201.9821895  162.33000922 227.05834073 201.63109517
#  196.21960754 194.28652047 186.75238434 167.39040251 227.24444321
#  211.99006847 198.03957427 223.1157255  211.99006847 203.75374368
#  205.94937431 247.72420309 219.5242046  186.75238434 220.29088833
#  235.8963574  224.58459789 220.82808514 246.2553307  230.48486978
#  199.81112844 185.28351195 244.13268219 196.21960754 205.22261607
#  190.34390524 192.65265623 251.66681832 204.10483801 220.99307699
#  194.12152862 194.47262295 177.04718715 185.1185201  207.88246139
#  213.45894086 169.86414535 201.28000084 196.57070187 213.10784653
#  222.95073365 211.63897414 207.88246139 213.45894086 186.58739249
#  244.13268219 211.99006847 192.27699231 170.21523968 208.81413697
#  204.10483801 196.21960754 188.68547141 177.74937582 177.04718715
#  184.93241762 161.97891489 211.63897414 217.05046176 215.41659752
#  158.03629966 175.27563298 169.51305102 196.21960754 194.12152862
#  227.24444321 196.21960754 247.72420309 209.1652313  171.33301774
#  227.05834073 192.27699231 167.03930818 162.33000922 193.7458647
#  204.10483801 209.54089521 178.86715388 235.12967367 158.03629966
#  216.88546991 205.22261607 220.64198266 239.83897263 234.42748501]

# %%
# Evaluating the model
print("Score on Test Data : ",ridge.score(attr_test,target_test))
print("Score on Training Data : ",ridge.score(attr_train,target_train))
# Out:
# Score on Test Data :  0.13814753651744904
# Score on Training Data :  0.28249616218692875

# %% [markdown]
# ### Section 9. Heat Map

# %%
# Encode the columns for example: 'Gender' column --> 0 for female, 1 for Male
df1['gender'] = label_encoder.fit_transform(df1['gender'])
df1['race/ethnicity'] = label_encoder.fit_transform(df1['race/ethnicity'])
df1['parental level of education'] = label_encoder.fit_transform(df1['parental level of education'])
df1['test preparation course'] = label_encoder.fit_transform(df1['test preparation course'])
df1['lunch'] = label_encoder.fit_transform(df1['lunch'])
# Adding total_score column which combines the math,reading,and writing score
df1['total_score'] = sum([df1['math score'],df1['reading score'],df1['writing score']])

# %%
# Creating the heatmap
import seaborn as sns 
correlation = df1.corr()
plt.figure(figsize = (10,6))

sns.heatmap(correlation  , annot = True , linewidth = 1)
# Out:
# <Axes: >
